# %% [markdown]
# <a href="https://colab.research.google.com/github/MoloZzz/nn/blob/main/Lec9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Які переваги мережі CNN в порівнянні з повно-зв'язною нейронною мережею для класифікації зображень?

# %% [markdown]
# Локальні патерни: CNN може ефективно розпізнавати локальні патерни в зображеннях завдяки використанню згорткових шарів та пулінгу. Це дозволяє їм краще виявляти просторові особливості.
#
# Спільне використання ваг: Згорткові шари використовують спільні ваги для різних областей вхідного зображення, що дозволяє ефективно використовувати обмежені ресурси та робить мережу менш вразливою до перенавчання.
#
# Переносність образів: Мережі CNN можуть легко адаптуватися до різних розмірів та пропорцій зображень, що робить їх більш переносними.
#
# Зниження розмірності: Пулінгові шари дозволяють знижувати розмірність карт ознак, зберігаючи при цьому важливі інформаційні характеристики.
#
# Виявлення ієрархічних ознак: Мережі CNN можуть автоматично вивчати ієрархічні ознаки від простих до більш складних, що корисно при аналізі зображень.

# %% [markdown]
# Чи може мережа СNN розпізнати одне і те саме зображення, але з іншого ракурсу. Обгрунтуйте

# %% [markdown]
# Так, мережі CNN можуть бути стійкими до змін в ракурсі зображення через їх властивість інваріантності до зсувів. Згорткові шари в мережах CNN можуть розпізнавати образи, незалежно від їх положення в зображенні. Це робить мережі CNN більш стійкими до змін розташування об'єктів на зображенні та різних ракурсів.
#
# Однак інваріантність до змін розташування не завжди гарантує повну інваріантність до змін ракурсу, особливо якщо ракурси змінюються дуже суттєво. У деяких випадках може бути корисним використання аугментації даних для тренування мережі на зображеннях з різними ракурсами та умовами освітлення для поліпшення її загальної роботи.
